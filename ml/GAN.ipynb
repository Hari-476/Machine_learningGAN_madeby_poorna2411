# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Define a basic transform
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %%
train_dataset = datasets.CIFAR10(root='./data',\
              train=True, download=True, transform=transform)
dataloader = torch.utils.data.DataLoader(train_dataset, \
                                batch_size=32, shuffle=True)
# Out:
# 100%|██████████| 170M/170M [01:14<00:00, 2.30MB/s]

# %%
# Hyperparameters
latent_dim = 100
lr = 0.0002
beta1 = 0.5
beta2 = 0.999
num_epochs = 10

# %%
# Define the generator
class Generator(nn.Module):
    def __init__(self, latent_dim):
        super(Generator, self).__init__()

        self.model = nn.Sequential(
            nn.Linear(latent_dim, 128 * 8 * 8),
            nn.ReLU(),
            nn.Unflatten(1, (128, 8, 8)),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128, momentum=0.78),
            nn.ReLU(),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64, momentum=0.78),
            nn.ReLU(),
            nn.Conv2d(64, 3, kernel_size=3, padding=1),
            nn.Tanh()
        )

    def forward(self, z):
        img = self.model(z)
        return img

# %%
# Define the discriminator
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.model = nn.Sequential(
        nn.Conv2d(3, 32, kernel_size=3, stride=2, padding=1),
        nn.LeakyReLU(0.2),
        nn.Dropout(0.25),
        nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1),
        nn.ZeroPad2d((0, 1, 0, 1)),
        nn.BatchNorm2d(64, momentum=0.82),
        nn.LeakyReLU(0.25),
        nn.Dropout(0.25),
        nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
        nn.BatchNorm2d(128, momentum=0.82),
        nn.LeakyReLU(0.2),
        nn.Dropout(0.25),
        nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
        nn.BatchNorm2d(256, momentum=0.8),
        nn.LeakyReLU(0.25),
        nn.Dropout(0.25),
        nn.Flatten(),
        nn.Linear(256 * 5 * 5, 1),
        nn.Sigmoid()
    )

    def forward(self, img):
        validity = self.model(img)
        return validity

# %%
# Define the generator and discriminator
# Initialize generator and discriminator
generator = Generator(latent_dim).to(device)
discriminator = Discriminator().to(device)
# Loss function
adversarial_loss = nn.BCELoss()
# Optimizers
optimizer_G = optim.Adam(generator.parameters()\
                         , lr=lr, betas=(beta1, beta2))
optimizer_D = optim.Adam(discriminator.parameters()\
                         , lr=lr, betas=(beta1, beta2))

# %%
# Training loop
for epoch in range(num_epochs):
    for i, batch in enumerate(dataloader):
       # Convert list to tensor
        real_images = batch[0].to(device)
        # Adversarial ground truths
        valid = torch.ones(real_images.size(0), 1, device=device)
        fake = torch.zeros(real_images.size(0), 1, device=device)
        # Configure input
        real_images = real_images.to(device)

        # ---------------------
        #  Train Discriminator
        # ---------------------
        optimizer_D.zero_grad()
        # Sample noise as generator input
        z = torch.randn(real_images.size(0), latent_dim, device=device)
        # Generate a batch of images
        fake_images = generator(z)

        # Measure discriminator's ability
        # to classify real and fake images
        real_loss = adversarial_loss(discriminator\
                                     (real_images), valid)
        fake_loss = adversarial_loss(discriminator\
                                     (fake_images.detach()), fake)
        d_loss = (real_loss + fake_loss) / 2
        # Backward pass and optimize
        d_loss.backward()
        optimizer_D.step()

        # -----------------
        #  Train Generator
        # -----------------

        optimizer_G.zero_grad()
        # Generate a batch of images
        gen_images = generator(z)
        # Adversarial loss
        g_loss = adversarial_loss(discriminator(gen_images), valid)
        # Backward pass and optimize
        g_loss.backward()
        optimizer_G.step()
        # ---------------------
        #  Progress Monitoring
        # ---------------------
        if (i + 1) % 100 == 0:
            print(
                f"Epoch [{epoch+1}/{num_epochs}]\
                        Batch {i+1}/{len(dataloader)} "
                f"Discriminator Loss: {d_loss.item():.4f} "
                f"Generator Loss: {g_loss.item():.4f}"
            )
    # Save generated images for every epoch
    if (epoch + 1) % 10 == 0:
        with torch.no_grad():
            z = torch.randn(16, latent_dim, device=device)
            generated = generator(z).detach().cpu()
            grid = torchvision.utils.make_grid(generated,\
                                        nrow=4, normalize=True)
            plt.imshow(np.transpose(grid, (1, 2, 0)))
            plt.axis("off")
            plt.show()
# Out:
# Epoch [1/10]                        Batch 100/1563 Discriminator Loss: 0.5522 Generator Loss: 1.3659
# Epoch [1/10]                        Batch 200/1563 Discriminator Loss: 0.6573 Generator Loss: 1.2984
# Epoch [1/10]                        Batch 300/1563 Discriminator Loss: 0.6346 Generator Loss: 0.8781
# Epoch [1/10]                        Batch 400/1563 Discriminator Loss: 0.8261 Generator Loss: 0.8537
# Epoch [1/10]                        Batch 500/1563 Discriminator Loss: 0.5513 Generator Loss: 1.1264
# Epoch [1/10]                        Batch 600/1563 Discriminator Loss: 0.6299 Generator Loss: 0.9738
# Epoch [1/10]                        Batch 700/1563 Discriminator Loss: 0.7087 Generator Loss: 0.7494
# Epoch [1/10]                        Batch 800/1563 Discriminator Loss: 0.7881 Generator Loss: 0.8199
# Epoch [1/10]                        Batch 900/1563 Discriminator Loss: 0.6101 Generator Loss: 1.0408
# Epoch [1/10]                        Batch 1000/1563 Discriminator Loss: 0.6511 Generator Loss: 0.9303
# Epoch [1/10]                        Batch 1100/1563 Discriminator Loss: 0.6689 Generator Loss: 1.0864
# Epoch [1/10]                        Batch 1200/1563 Discriminator Loss: 0.6622 Generator Loss: 0.9323
# Epoch [1/10]                        Batch 1300/1563 Discriminator Loss: 0.7206 Generator Loss: 0.8919
# Epoch [1/10]                        Batch 1400/1563 Discriminator Loss: 0.7398 Generator Loss: 1.0855
# Epoch [1/10]                        Batch 1500/1563 Discriminator Loss: 0.4521 Generator Loss: 1.5364
# Epoch [2/10]                        Batch 100/1563 Discriminator Loss: 0.8871 Generator Loss: 0.7157
# Epoch [2/10]                        Batch 200/1563 Discriminator Loss: 0.6063 Generator Loss: 1.0062
# Epoch [2/10]                        Batch 300/1563 Discriminator Loss: 0.6487 Generator Loss: 1.3381
# Epoch [2/10]                        Batch 400/1563 Discriminator Loss: 0.6751 Generator Loss: 1.2079
# Epoch [2/10]                        Batch 500/1563 Discriminator Loss: 0.5675 Generator Loss: 1.1242
# Epoch [2/10]                        Batch 600/1563 Discriminator Loss: 0.5060 Generator Loss: 1.0834
# Epoch [2/10]                        Batch 700/1563 Discriminator Loss: 0.6469 Generator Loss: 0.8788
# Epoch [2/10]                        Batch 800/1563 Discriminator Loss: 0.7311 Generator Loss: 0.7404
# Epoch [2/10]                        Batch 900/1563 Discriminator Loss: 0.7980 Generator Loss: 0.7605
# Epoch [2/10]                        Batch 1000/1563 Discriminator Loss: 0.6049 Generator Loss: 1.2362
# Epoch [2/10]                        Batch 1100/1563 Discriminator Loss: 0.7641 Generator Loss: 1.1933
# Epoch [2/10]                        Batch 1200/1563 Discriminator Loss: 0.7969 Generator Loss: 1.0257
# Epoch [2/10]                        Batch 1300/1563 Discriminator Loss: 0.7592 Generator Loss: 0.9896
# Epoch [2/10]                        Batch 1400/1563 Discriminator Loss: 0.5640 Generator Loss: 1.2494
# Epoch [2/10]                        Batch 1500/1563 Discriminator Loss: 0.8560 Generator Loss: 0.7364
# Epoch [3/10]                        Batch 100/1563 Discriminator Loss: 0.6209 Generator Loss: 0.8024
# Epoch [3/10]                        Batch 200/1563 Discriminator Loss: 0.6079 Generator Loss: 0.9558
# Epoch [3/10]                        Batch 300/1563 Discriminator Loss: 0.5721 Generator Loss: 1.7780
# Epoch [3/10]                        Batch 400/1563 Discriminator Loss: 0.4706 Generator Loss: 1.1215
# Epoch [3/10]                        Batch 500/1563 Discriminator Loss: 0.5876 Generator Loss: 1.0798
# Epoch [3/10]                        Batch 600/1563 Discriminator Loss: 0.6776 Generator Loss: 0.8480
# Epoch [3/10]                        Batch 700/1563 Discriminator Loss: 0.7546 Generator Loss: 1.2642
# Epoch [3/10]                        Batch 800/1563 Discriminator Loss: 0.5945 Generator Loss: 0.8285
# Epoch [3/10]                        Batch 900/1563 Discriminator Loss: 0.5165 Generator Loss: 1.3709
# Epoch [3/10]                        Batch 1000/1563 Discriminator Loss: 0.6669 Generator Loss: 1.0986
# Epoch [3/10]                        Batch 1100/1563 Discriminator Loss: 0.5891 Generator Loss: 0.7929
# Epoch [3/10]                        Batch 1200/1563 Discriminator Loss: 0.7523 Generator Loss: 1.0475
# Epoch [3/10]                        Batch 1300/1563 Discriminator Loss: 0.5078 Generator Loss: 1.0714
# Epoch [3/10]                        Batch 1400/1563 Discriminator Loss: 0.4806 Generator Loss: 1.1670
# Epoch [3/10]                        Batch 1500/1563 Discriminator Loss: 0.4829 Generator Loss: 1.3014
# Epoch [4/10]                        Batch 100/1563 Discriminator Loss: 0.5634 Generator Loss: 1.4271
# Epoch [4/10]                        Batch 200/1563 Discriminator Loss: 0.4899 Generator Loss: 0.9661
# Epoch [4/10]                        Batch 300/1563 Discriminator Loss: 0.7363 Generator Loss: 1.1171
# Epoch [4/10]                        Batch 400/1563 Discriminator Loss: 0.6213 Generator Loss: 1.4183
# Epoch [4/10]                        Batch 500/1563 Discriminator Loss: 0.5202 Generator Loss: 1.0018
# Epoch [4/10]                        Batch 600/1563 Discriminator Loss: 0.4686 Generator Loss: 0.7657
# Epoch [4/10]                        Batch 700/1563 Discriminator Loss: 0.4464 Generator Loss: 1.5364
# Epoch [4/10]                        Batch 800/1563 Discriminator Loss: 0.5282 Generator Loss: 2.1708
# Epoch [4/10]                        Batch 900/1563 Discriminator Loss: 0.5123 Generator Loss: 1.2929
# Epoch [4/10]                        Batch 1000/1563 Discriminator Loss: 0.6216 Generator Loss: 1.2292
# Epoch [4/10]                        Batch 1100/1563 Discriminator Loss: 0.3635 Generator Loss: 1.8805
# Epoch [4/10]                        Batch 1200/1563 Discriminator Loss: 0.4221 Generator Loss: 1.6082
# Epoch [4/10]                        Batch 1300/1563 Discriminator Loss: 0.5305 Generator Loss: 1.5487
# Epoch [4/10]                        Batch 1400/1563 Discriminator Loss: 0.7238 Generator Loss: 1.2200
# Epoch [4/10]                        Batch 1500/1563 Discriminator Loss: 0.6897 Generator Loss: 0.9432
# Epoch [5/10]                        Batch 100/1563 Discriminator Loss: 0.4833 Generator Loss: 1.1568
# Epoch [5/10]                        Batch 200/1563 Discriminator Loss: 0.4682 Generator Loss: 1.8007
# Epoch [5/10]                        Batch 300/1563 Discriminator Loss: 0.5256 Generator Loss: 0.9886
# Epoch [5/10]                        Batch 400/1563 Discriminator Loss: 0.4708 Generator Loss: 1.5232
# Epoch [5/10]                        Batch 500/1563 Discriminator Loss: 0.6900 Generator Loss: 1.1108
# Epoch [5/10]                        Batch 600/1563 Discriminator Loss: 0.9563 Generator Loss: 1.0338
# Epoch [5/10]                        Batch 700/1563 Discriminator Loss: 0.5121 Generator Loss: 1.8062
# Epoch [5/10]                        Batch 800/1563 Discriminator Loss: 0.4123 Generator Loss: 1.3820
# Epoch [5/10]                        Batch 900/1563 Discriminator Loss: 0.6113 Generator Loss: 1.5508
# Epoch [5/10]                        Batch 1000/1563 Discriminator Loss: 0.4879 Generator Loss: 1.4505
# Epoch [5/10]                        Batch 1100/1563 Discriminator Loss: 0.6029 Generator Loss: 1.0269
# Epoch [5/10]                        Batch 1200/1563 Discriminator Loss: 0.6077 Generator Loss: 1.9545
# Epoch [5/10]                        Batch 1300/1563 Discriminator Loss: 0.7219 Generator Loss: 1.1592
# Epoch [5/10]                        Batch 1400/1563 Discriminator Loss: 0.6461 Generator Loss: 1.5429
# Epoch [5/10]                        Batch 1500/1563 Discriminator Loss: 0.4866 Generator Loss: 0.9312
# Epoch [6/10]                        Batch 100/1563 Discriminator Loss: 0.5609 Generator Loss: 1.5769
# Epoch [6/10]                        Batch 200/1563 Discriminator Loss: 1.0770 Generator Loss: 0.4550
# Epoch [6/10]                        Batch 300/1563 Discriminator Loss: 0.4819 Generator Loss: 1.6472
# Epoch [6/10]                        Batch 400/1563 Discriminator Loss: 0.5586 Generator Loss: 1.3338
# Epoch [6/10]                        Batch 500/1563 Discriminator Loss: 0.4689 Generator Loss: 2.0731
# Epoch [6/10]                        Batch 600/1563 Discriminator Loss: 0.6452 Generator Loss: 0.9500
# Epoch [6/10]                        Batch 700/1563 Discriminator Loss: 0.6638 Generator Loss: 0.8330
# Epoch [6/10]                        Batch 800/1563 Discriminator Loss: 0.5504 Generator Loss: 1.3135
# Epoch [6/10]                        Batch 900/1563 Discriminator Loss: 0.8039 Generator Loss: 1.0445
# Epoch [6/10]                        Batch 1000/1563 Discriminator Loss: 0.5916 Generator Loss: 1.1671
# Epoch [6/10]                        Batch 1100/1563 Discriminator Loss: 0.6750 Generator Loss: 1.1418
# Epoch [6/10]                        Batch 1200/1563 Discriminator Loss: 1.0152 Generator Loss: 1.1545
# Epoch [6/10]                        Batch 1300/1563 Discriminator Loss: 0.5484 Generator Loss: 1.1363
# Epoch [6/10]                        Batch 1400/1563 Discriminator Loss: 0.4711 Generator Loss: 0.9114
# Epoch [6/10]                        Batch 1500/1563 Discriminator Loss: 0.5228 Generator Loss: 1.6309
# Epoch [7/10]                        Batch 100/1563 Discriminator Loss: 0.6638 Generator Loss: 1.6165
# Epoch [7/10]                        Batch 200/1563 Discriminator Loss: 0.7391 Generator Loss: 0.8739
# Epoch [7/10]                        Batch 300/1563 Discriminator Loss: 0.3445 Generator Loss: 1.2908
# Epoch [7/10]                        Batch 400/1563 Discriminator Loss: 0.4999 Generator Loss: 1.0318
# Epoch [7/10]                        Batch 500/1563 Discriminator Loss: 0.5245 Generator Loss: 1.2853
# Epoch [7/10]                        Batch 600/1563 Discriminator Loss: 0.4685 Generator Loss: 1.2579
# Epoch [7/10]                        Batch 700/1563 Discriminator Loss: 0.6538 Generator Loss: 1.5562
# Epoch [7/10]                        Batch 800/1563 Discriminator Loss: 0.5868 Generator Loss: 0.8802
# Epoch [7/10]                        Batch 900/1563 Discriminator Loss: 0.9604 Generator Loss: 0.9823
# Epoch [7/10]                        Batch 1000/1563 Discriminator Loss: 0.7964 Generator Loss: 1.2819
# Epoch [7/10]                        Batch 1100/1563 Discriminator Loss: 0.4453 Generator Loss: 1.8129
# Epoch [7/10]                        Batch 1200/1563 Discriminator Loss: 0.7584 Generator Loss: 0.6070
# Epoch [7/10]                        Batch 1300/1563 Discriminator Loss: 0.4995 Generator Loss: 1.0352
# Epoch [7/10]                        Batch 1400/1563 Discriminator Loss: 0.5572 Generator Loss: 1.9517
# Epoch [7/10]                        Batch 1500/1563 Discriminator Loss: 0.7312 Generator Loss: 1.2028
# Epoch [8/10]                        Batch 100/1563 Discriminator Loss: 1.0004 Generator Loss: 0.9458
# Epoch [8/10]                        Batch 200/1563 Discriminator Loss: 0.5590 Generator Loss: 1.6541
# Epoch [8/10]                        Batch 300/1563 Discriminator Loss: 0.6731 Generator Loss: 1.2040
# Epoch [8/10]                        Batch 400/1563 Discriminator Loss: 0.7296 Generator Loss: 1.3689
# Epoch [8/10]                        Batch 500/1563 Discriminator Loss: 0.6873 Generator Loss: 0.7817
# Epoch [8/10]                        Batch 600/1563 Discriminator Loss: 0.7448 Generator Loss: 0.8475
# Epoch [8/10]                        Batch 700/1563 Discriminator Loss: 0.5979 Generator Loss: 1.3248
# Epoch [8/10]                        Batch 800/1563 Discriminator Loss: 0.4935 Generator Loss: 2.4867
# Epoch [8/10]                        Batch 900/1563 Discriminator Loss: 0.7132 Generator Loss: 0.7658
# Epoch [8/10]                        Batch 1000/1563 Discriminator Loss: 0.4270 Generator Loss: 2.2921
# Epoch [8/10]                        Batch 1100/1563 Discriminator Loss: 0.3880 Generator Loss: 1.4245
# Epoch [8/10]                        Batch 1200/1563 Discriminator Loss: 0.6030 Generator Loss: 1.0101
# Epoch [8/10]                        Batch 1300/1563 Discriminator Loss: 0.5356 Generator Loss: 1.2203
# Epoch [8/10]                        Batch 1400/1563 Discriminator Loss: 0.7036 Generator Loss: 1.5839
# Epoch [8/10]                        Batch 1500/1563 Discriminator Loss: 0.4985 Generator Loss: 1.1466
# Epoch [9/10]                        Batch 100/1563 Discriminator Loss: 0.6332 Generator Loss: 1.1735
# Epoch [9/10]                        Batch 200/1563 Discriminator Loss: 0.7970 Generator Loss: 0.6981
# Epoch [9/10]                        Batch 300/1563 Discriminator Loss: 0.4870 Generator Loss: 1.6592
# Epoch [9/10]                        Batch 400/1563 Discriminator Loss: 0.6751 Generator Loss: 1.6690
# Epoch [9/10]                        Batch 500/1563 Discriminator Loss: 0.7170 Generator Loss: 1.2790
# Epoch [9/10]                        Batch 600/1563 Discriminator Loss: 0.6599 Generator Loss: 0.8841
# Epoch [9/10]                        Batch 700/1563 Discriminator Loss: 0.9065 Generator Loss: 1.1347
# Epoch [9/10]                        Batch 800/1563 Discriminator Loss: 0.5762 Generator Loss: 0.9817
# Epoch [9/10]                        Batch 900/1563 Discriminator Loss: 0.8127 Generator Loss: 0.5650
# Epoch [9/10]                        Batch 1000/1563 Discriminator Loss: 0.5518 Generator Loss: 0.9619
# Epoch [9/10]                        Batch 1100/1563 Discriminator Loss: 0.9423 Generator Loss: 0.6092
# Epoch [9/10]                        Batch 1200/1563 Discriminator Loss: 0.6683 Generator Loss: 1.7271
# Epoch [9/10]                        Batch 1300/1563 Discriminator Loss: 0.6767 Generator Loss: 1.4597
# Epoch [9/10]                        Batch 1400/1563 Discriminator Loss: 0.6993 Generator Loss: 1.2634
# Epoch [9/10]                        Batch 1500/1563 Discriminator Loss: 0.6866 Generator Loss: 0.6584
# Epoch [10/10]                        Batch 100/1563 Discriminator Loss: 0.4731 Generator Loss: 1.4532
# Epoch [10/10]                        Batch 200/1563 Discriminator Loss: 0.8583 Generator Loss: 1.0048
# Epoch [10/10]                        Batch 300/1563 Discriminator Loss: 0.7142 Generator Loss: 0.8577
# Epoch [10/10]                        Batch 400/1563 Discriminator Loss: 0.6658 Generator Loss: 1.2146
# Epoch [10/10]                        Batch 500/1563 Discriminator Loss: 0.4045 Generator Loss: 1.4080
# Epoch [10/10]                        Batch 600/1563 Discriminator Loss: 0.4984 Generator Loss: 1.5249
# Epoch [10/10]                        Batch 700/1563 Discriminator Loss: 0.5473 Generator Loss: 1.2208
# Epoch [10/10]                        Batch 800/1563 Discriminator Loss: 0.7034 Generator Loss: 1.4453
# Epoch [10/10]                        Batch 900/1563 Discriminator Loss: 0.6982 Generator Loss: 1.1799
# Epoch [10/10]                        Batch 1000/1563 Discriminator Loss: 0.5583 Generator Loss: 1.2038
# Epoch [10/10]                        Batch 1100/1563 Discriminator Loss: 0.5466 Generator Loss: 1.0636
# Epoch [10/10]                        Batch 1200/1563 Discriminator Loss: 0.3805 Generator Loss: 1.4203
# Epoch [10/10]                        Batch 1300/1563 Discriminator Loss: 0.6135 Generator Loss: 1.5924
# Epoch [10/10]                        Batch 1400/1563 Discriminator Loss: 1.1169 Generator Loss: 0.8932
# Epoch [10/10]                        Batch 1500/1563 Discriminator Loss: 0.3963 Generator Loss: 1.2652
